# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import calendar
from pprint import pprint


file2019 = "2019.csv"
file2020 = "2020.csv"

crime_data2019 = pd.read_csv(file2019,low_memory=False)
crime_data2020 = pd.read_csv(file2020,low_memory=False)

# %%
crime_data2019.head()
# Out:
#    Unnamed: 0  Incident Number     Highest Offense Description  \
# 0          22       2019571113  ASSAULT  CONTACT-SEXUAL NATURE
# 1         251      20191870265                             DWI
# 2         336      20195009315                PROTECTIVE ORDER
# 3         342       2019602041     AGG ASLT STRANGLE/SUFFOCATE
# 4         470      20191000704           BURGLARY OF RESIDENCE
#
#    Highest Offense Code Family Violence      Occurred Date Time Occurred Date  \
# 0                   902               Y  02/24/2019 09:00:00 PM    2019-02-24
# 1                  2100               N  07/06/2019 03:28:00 AM    2019-07-06
# 2                  3829               N  03/05/2019 04:47:00 PM    2019-03-05
# 3                   410               Y  03/01/2019 11:55:00 PM    2019-03-01
# 4                   500               N  04/09/2019 06:00:00 PM    2019-04-09
#
#    Occurred Time        Report Date Time Report Date  ...  Census Tract  \
# 0         2100.0  02/26/2019 04:00:00 PM  02/26/2019  ...         17.77
# 1          328.0  07/06/2019 07:08:00 AM  07/06/2019  ...           NaN
# 2         1647.0  03/05/2019 04:47:00 PM  03/05/2019  ...           NaN
# 3         2355.0  03/01/2019 11:55:00 PM  03/01/2019  ...         18.49
# 4         1800.0  04/10/2019 10:24:00 AM  04/10/2019  ...         21.13
#
#   Clearance Status Clearance Date  UCR Category  Category Description  \
# 0                N     03/06/2019           NaN                   NaN
# 1                C     07/10/2019           NaN                   NaN
# 2                N     03/05/2019           NaN                   NaN
# 3                C     03/02/2019           13A    Aggravated Assault
# 4                N     04/11/2019           220              Burglary
#
#   X-coordinate Y-coordinate   Latitude  Longitude                     Location
# 0          0.0          0.0        NaN        NaN                          NaN
# 1    3123140.0    3123140.0  30.233876 -97.715765  (30.23387556, -97.71576502)
# 2          NaN          NaN        NaN        NaN                          NaN
# 3          0.0          0.0        NaN        NaN                          NaN
# 4    3137307.0    3137307.0  30.311622 -97.668747  (30.31162194, -97.66874689)
#
# [5 rows x 28 columns]

# %%
crime_data2020
# Out:
#        Unnamed: 0  Incident Number     Highest Offense Description  \
# 0             287      20205011264               SUSPICIOUS PERSON
# 1             308      20205009665             BURGLARY OF VEHICLE
# 2             967       2020741842        UNLAWFUL CARRYING WEAPON
# 3             998      20201741205  SEXUAL ASSAULT OF CHILD/OBJECT
# 4            1119       2020671670               CRIMINAL TRESPASS
# ...           ...              ...                             ...
# 49066     2257585       2020780400                      AUTO THEFT
# 49067     2257594       2020951072                             DWI
# 49068     2257600      20205014196             DISTURBANCE - OTHER
# 49069     2257613       2020970960              FAMILY DISTURBANCE
# 49070     2257617       2020951013            THEFT BY SHOPLIFTING
#
#        Highest Offense Code Family Violence      Occurred Date Time  \
# 0                      3403               N  03/19/2020 04:35:00 AM
# 1                       601               N  03/06/2020 03:30:00 AM
# 2                      1500               N  03/14/2020 11:08:00 PM
# 3                      1707               Y  06/23/2020 04:26:00 AM
# 4                      2716               N  03/07/2020 10:00:00 PM
# ...                     ...             ...                     ...
# 49066                   700               N  03/18/2020 10:07:00 AM
# 49067                  2100               N  04/04/2020 10:13:00 PM
# 49068                  3401               N  04/10/2020 03:46:00 PM
# 49069                  3400               N  04/06/2020 05:08:00 PM
# 49070                   607               N  04/04/2020 08:01:00 PM
#
#       Occurred Date  Occurred Time        Report Date Time Report Date  ...  \
# 0        2020-03-19          435.0  03/19/2020 10:46:00 AM  03/19/2020  ...
# 1        2020-03-06          330.0  03/08/2020 10:22:00 AM  03/08/2020  ...
# 2        2020-03-14         2308.0  03/14/2020 11:08:00 PM  03/14/2020  ...
# 3        2020-06-23          426.0  06/23/2020 04:26:00 AM  06/23/2020  ...
# 4        2020-03-07         2200.0  03/07/2020 10:00:00 PM  03/07/2020  ...
# ...             ...            ...                     ...         ...  ...
# 49066    2020-03-18         1007.0  03/18/2020 10:07:00 AM  03/18/2020  ...
# 49067    2020-04-04         2213.0  04/04/2020 10:13:00 PM  04/04/2020  ...
# 49068    2020-04-10         1546.0  04/10/2020 04:46:00 PM  04/10/2020  ...
# 49069    2020-04-06         1708.0  04/06/2020 05:08:00 PM  04/06/2020  ...
# 49070    2020-04-04         2001.0  04/04/2020 08:01:00 PM  04/04/2020  ...
#
#        Census Tract Clearance Status Clearance Date  UCR Category  \
# 0               NaN              NaN            NaN           NaN
# 1               NaN                N     03/16/2020           23F
# 2               NaN                C     03/15/2020           NaN
# 3               NaN              NaN            NaN           11C
# 4               NaN              NaN            NaN           NaN
# ...             ...              ...            ...           ...
# 49066         18.35                N     03/23/2020           240
# 49067           NaN                C     04/05/2020           NaN
# 49068         24.22              NaN            NaN           NaN
# 49069           NaN              NaN            NaN           NaN
# 49070           NaN                C     04/04/2020           23C
#
#        Category Description X-coordinate Y-coordinate   Latitude  Longitude  \
# 0                       NaN    3127385.0    3127385.0  30.423368 -97.697147
# 1                     Theft    3116318.0    3116318.0  30.232921 -97.737399
# 2                       NaN    3123129.0    3123129.0  30.303287 -97.713917
# 3                      Rape          0.0          0.0        NaN        NaN
# 4                       NaN    3112984.0    3112984.0  30.265437 -97.747088
# ...                     ...          ...          ...        ...        ...
# 49066            Auto Theft    3140018.0    3140018.0  30.385045 -97.658117
# 49067                   NaN    3107822.0    3107822.0  30.438232 -97.758836
# 49068                   NaN    3100503.0    3100503.0  30.189417 -97.788637
# 49069                   NaN    3128170.0    3128170.0  30.349500 -97.696676
# 49070                 Theft    3111086.0    3111086.0  30.218415 -97.754358
#
#                           Location
# 0      (30.42336836, -97.69714681)
# 1      (30.23292142, -97.73739875)
# 2      (30.30328695, -97.71391722)
# 3                              NaN
# 4      (30.26543655, -97.74708803)
# ...                            ...
# 49066  (30.38504521, -97.65811749)
# 49067  (30.43823214, -97.75883565)
# 49068  (30.18941679, -97.78863679)
# 49069  (30.34950001, -97.69667616)
# 49070  (30.21841503, -97.75435779)
#
# [49071 rows x 28 columns]

# %%
runaway2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("RUNAWAY")]
print(f"runaway 2019: {len(runaway2019)}")

runaway2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("RUNAWAY")]
print(f"runaway 2020: {len(runaway2020)}")
# Out:
# runaway 2019: 992
# runaway 2020: 656

# %%
animal2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("ANIMAL")]
print(f"animal 2019: {len(animal2019)}")

animal2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("ANIMAL")]
print(f"animal 2020: {len(animal2020)}")
# Out:
# animal 2019: 108
# animal 2020: 85

# %%
kidnapping2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("KIDNAPPING")]
print(f"kidnapping 2019: {len(kidnapping2019)}")

kidnapping2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("KIDNAPPING")]
print(f"kidnapping 2020: {len(kidnapping2020)}")
# Out:
# kidnapping 2019: 10
# kidnapping 2020: 0

# %%
weapon2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("WEAPON")]
print(f"weapon 2019: {len(weapon2019)}")

weapon2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("WEAPON")]
print(f"weapon 2020: {len(weapon2020)}")
# Out:
# weapon 2019: 429
# weapon 2020: 457

# %%
# GATHER Highest Offense Descriptions that are drug related in order to combine similar offenses

# %%
drug2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("DRUG")]
print(f"drug 2019: {len(drug2019)}")

drug2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("DRUG")]
print(f"drug 2020: {len(drug2020)}")
# Out:
# drug 2019: 552
# drug 2020: 599

# %%
narcotic2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("NARCOTIC")]
print(f"narcotic 2019: {len(narcotic2019)}")

narcotic2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("NARCOTIC")]
print(f"narcotic 2020: {len(narcotic2020)}")
# Out:
# narcotic 2019: 1179
# narcotic 2020: 703

# %%
alcohol2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("ALCOHOL")]
print(f"alcohol 2019: {len(alcohol2019)}")

alcohol2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("ALCOHOL")]
print(f"alcohol 2020: {len(alcohol2020)}")
# Out:
# alcohol 2019: 45
# alcohol 2020: 20

# %%
tobacco2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("TOBACCO")]
print(f"tobacco 2019: {len(tobacco2019)}")

tobacco2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("TOBACCO")]
print(f"tobacco 2020: {len(tobacco2020)}")
# Out:
# tobacco 2019: 2
# tobacco 2020: 2

# %%
marijuana2019 = crime_data2019[crime_data2019['Highest Offense Description'].str.contains("MARIJUANA")]
print(f"marijuana 2019: {len(marijuana2019)}")

marijuana2020 = crime_data2020[crime_data2020['Highest Offense Description'].str.contains("MARIJUANA")]
print(f"marijuana 2020: {len(marijuana2020)}")
# Out:
# marijuana 2019: 756
# marijuana 2020: 422

# %%
marijuana2019.columns
# Out:
# Index(['Unnamed: 0', 'Incident Number', 'Highest Offense Description',
#        'Highest Offense Code', 'Family Violence', 'Occurred Date Time',
#        'Occurred Date', 'Occurred Time', 'Report Date Time', 'Report Date',
#        'Report Time', 'Location Type', 'Address', 'Zip Code',
#        'Council District', 'APD Sector', 'APD District', 'PRA', 'Census Tract',
#        'Clearance Status', 'Clearance Date', 'UCR Category',
#        'Category Description', 'X-coordinate', 'Y-coordinate', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
# Check to see if there are any values with mispelled or similar values in "Offense Type"
crime_data2019["Highest Offense Description"].value_counts()
# Out:
# BURGLARY OF VEHICLE               5968
# FAMILY DISTURBANCE                5106
# THEFT                             4730
# CRIMINAL MISCHIEF                 2752
# ASSAULT W/INJURY-FAM/DATE VIOL    1710
#                                   ...
# VOCO SOLICITATION PROHIBIT           1
# VIOL CITY ORDINANCE - TAXI           1
# VIOL CITY ORDINANCE - SMOKING        1
# DOC WINDOW PEEPING - PUB AREA        1
# COMPELLING PROSTITUTION              1
# Name: Highest Offense Description, Length: 299, dtype: int64

# %%
# Combining similar offenses together
drug2019_clean_df = crime_data2019.replace(
    {"VOCO - ALCOHOL  CONSUMPTION": "Drug Related", "VIOL CITY ORDINANCE - SMOKING": "Drug Related", "TOBACCO VIOL - UNDER AGE 17": "Drug Related", "POSSESSION OF MARIJUANA": "Drug Related", "POSS SYNTHETIC MARIJUANA": "Drug Related", "POSS OF PRESCRIPTION FORM": "Drug Related", "POSS OF DRUG PARAPHERNALIA": "Drug Related", "POSS OF ALCOHOL-AGE 16 & UNDER": "Drug Related", "POSS OF ALCOHOL - AGE 17 TO 20": "Drug Related", "POSS DANG DRUG": "Drug Related", "POSS CONTROLLED SUB/SYN NARC": "Drug Related", "POSS CONTROLLED SUB/OTHER": "Drug Related", "OBTAIN DANG DRUG BY FRAUD": "Drug Related", "MANF CONTROLLED SUB - OTHER": "Drug Related", "MAKING TOBACCO AVAIL TO MINOR": "Drug Related", "LIQUOR LAW VIOLATION/OTHER": "Drug Related", "DEL SYNTHETIC MARIJUANA": "Drug Related", "DEL OF DANG DRUG": "Drug Related", "DEL MARIJUANA": "Drug Related", "DEL CONTROLLED SUB/SYN NARC": "Drug Related", "DEL CONTROLLED SUB/NARCOTIC": "Drug Related", " CONTROLLED SUB VIOL - OTHER": "Drug Related"})
drug2019_clean_df
# Out:
#        Unnamed: 0  Incident Number     Highest Offense Description  \
# 0              22       2019571113  ASSAULT  CONTACT-SEXUAL NATURE
# 1             251      20191870265                             DWI
# 2             336      20195009315                PROTECTIVE ORDER
# 3             342       2019602041     AGG ASLT STRANGLE/SUFFOCATE
# 4             470      20191000704           BURGLARY OF RESIDENCE
# ...           ...              ...                             ...
# 52761     2257428      20191670210              FAMILY DISTURBANCE
# 52762     2257456       2019551195     AGG ASLT STRANGLE/SUFFOCATE
# 52763     2257457      20191932027      WARRANT ARREST NON TRAFFIC
# 52764     2257524      20191261939  TERRORISTIC THREAT-FAM/DAT VIO
# 52765     2257556      20191862056         CHILD CUSTODY INTERFERE
#
#        Highest Offense Code Family Violence      Occurred Date Time  \
# 0                       902               Y  02/24/2019 09:00:00 PM
# 1                      2100               N  07/06/2019 03:28:00 AM
# 2                      3829               N  03/05/2019 04:47:00 PM
# 3                       410               Y  03/01/2019 11:55:00 PM
# 4                       500               N  04/09/2019 06:00:00 PM
# ...                     ...             ...                     ...
# 52761                  3400               N  06/16/2019 02:21:00 AM
# 52762                   410               Y  02/24/2019 04:44:00 PM
# 52763                  3442               N  07/12/2019 10:40:00 PM
# 52764                  2704               Y  05/06/2019 02:00:00 PM
# 52765                  2001               N  07/05/2019 05:57:00 PM
#
#       Occurred Date  Occurred Time        Report Date Time Report Date  ...  \
# 0        2019-02-24         2100.0  02/26/2019 04:00:00 PM  02/26/2019  ...
# 1        2019-07-06          328.0  07/06/2019 07:08:00 AM  07/06/2019  ...
# 2        2019-03-05         1647.0  03/05/2019 04:47:00 PM  03/05/2019  ...
# 3        2019-03-01         2355.0  03/01/2019 11:55:00 PM  03/01/2019  ...
# 4        2019-04-09         1800.0  04/10/2019 10:24:00 AM  04/10/2019  ...
# ...             ...            ...                     ...         ...  ...
# 52761    2019-06-16          221.0  06/16/2019 02:21:00 AM  06/16/2019  ...
# 52762    2019-02-24         1644.0  02/24/2019 04:44:00 PM  02/24/2019  ...
# 52763    2019-07-12         2240.0  07/12/2019 10:40:00 PM  07/12/2019  ...
# 52764    2019-05-06         1400.0  05/07/2019 12:27:00 AM  05/07/2019  ...
# 52765    2019-07-05         1757.0  07/05/2019 05:57:00 PM  07/05/2019  ...
#
#        Census Tract Clearance Status Clearance Date  UCR Category  \
# 0             17.77                N     03/06/2019           NaN
# 1               NaN                C     07/10/2019           NaN
# 2               NaN                N     03/05/2019           NaN
# 3             18.49                C     03/02/2019           13A
# 4             21.13                N     04/11/2019           220
# ...             ...              ...            ...           ...
# 52761         24.31                N     11/21/2019           NaN
# 52762         19.00                C     02/24/2019           13A
# 52763         21.11              NaN            NaN           NaN
# 52764         24.33                N     05/28/2019           NaN
# 52765         24.28                N     07/17/2019           NaN
#
#        Category Description X-coordinate Y-coordinate   Latitude  Longitude  \
# 0                       NaN          0.0          0.0        NaN        NaN
# 1                       NaN    3123140.0    3123140.0  30.233876 -97.715765
# 2                       NaN          NaN          NaN        NaN        NaN
# 3        Aggravated Assault          0.0          0.0        NaN        NaN
# 4                  Burglary    3137307.0    3137307.0  30.311622 -97.668747
# ...                     ...          ...          ...        ...        ...
# 52761                   NaN    3117980.0    3117980.0  30.190296 -97.733282
# 52762    Aggravated Assault    3064189.0    3064189.0  30.259883 -97.901829
# 52763                   NaN    3134239.0    3134239.0  30.253582 -97.680068
# 52764                   NaN    3156400.0    3156400.0  30.172937 -97.612133
# 52765                   NaN    3100271.0    3100271.0  30.137407 -97.790740
#
#                           Location
# 0                              NaN
# 1      (30.23387556, -97.71576502)
# 2                              NaN
# 3                              NaN
# 4      (30.31162194, -97.66874689)
# ...                            ...
# 52761  (30.19029582, -97.73328214)
# 52762  (30.25988292, -97.90182915)
# 52763   (30.25358182, -97.6800683)
# 52764    (30.172937, -97.61213257)
# 52765  (30.13740669, -97.79073994)
#
# [52766 rows x 28 columns]

# %%
# Combining similar offenses together
drug2020_clean_df = crime_data2020.replace(
    {"VOCO - ALCOHOL  CONSUMPTION": "Drug Related", "VIOL CITY ORDINANCE - SMOKING": "Drug Related", "TOBACCO VIOL - UNDER AGE 17": "Drug Related", "POSSESSION OF MARIJUANA": "Drug Related", "POSS SYNTHETIC MARIJUANA": "Drug Related", "POSS OF PRESCRIPTION FORM": "Drug Related", "POSS OF DRUG PARAPHERNALIA": "Drug Related", "POSS OF ALCOHOL-AGE 16 & UNDER": "Drug Related", "POSS OF ALCOHOL - AGE 17 TO 20": "Drug Related", "POSS DANG DRUG": "Drug Related", "POSS CONTROLLED SUB/SYN NARC": "Drug Related", "POSS CONTROLLED SUB/OTHER": "Drug Related", "OBTAIN DANG DRUG BY FRAUD": "Drug Related", "MANF CONTROLLED SUB - OTHER": "Drug Related", "MAKING TOBACCO AVAIL TO MINOR": "Drug Related", "LIQUOR LAW VIOLATION/OTHER": "Drug Related", "DEL SYNTHETIC MARIJUANA": "Drug Related", "DEL OF DANG DRUG": "Drug Related", "DEL MARIJUANA": "Drug Related", "DEL CONTROLLED SUB/SYN NARC": "Drug Related", "DEL CONTROLLED SUB/NARCOTIC": "Drug Related", " CONTROLLED SUB VIOL - OTHER": "Drug Related"})
drug2020_clean_df
# Out:
#        Unnamed: 0  Incident Number     Highest Offense Description  \
# 0             287      20205011264               SUSPICIOUS PERSON
# 1             308      20205009665             BURGLARY OF VEHICLE
# 2             967       2020741842        UNLAWFUL CARRYING WEAPON
# 3             998      20201741205  SEXUAL ASSAULT OF CHILD/OBJECT
# 4            1119       2020671670               CRIMINAL TRESPASS
# ...           ...              ...                             ...
# 49066     2257585       2020780400                      AUTO THEFT
# 49067     2257594       2020951072                             DWI
# 49068     2257600      20205014196             DISTURBANCE - OTHER
# 49069     2257613       2020970960              FAMILY DISTURBANCE
# 49070     2257617       2020951013            THEFT BY SHOPLIFTING
#
#        Highest Offense Code Family Violence      Occurred Date Time  \
# 0                      3403               N  03/19/2020 04:35:00 AM
# 1                       601               N  03/06/2020 03:30:00 AM
# 2                      1500               N  03/14/2020 11:08:00 PM
# 3                      1707               Y  06/23/2020 04:26:00 AM
# 4                      2716               N  03/07/2020 10:00:00 PM
# ...                     ...             ...                     ...
# 49066                   700               N  03/18/2020 10:07:00 AM
# 49067                  2100               N  04/04/2020 10:13:00 PM
# 49068                  3401               N  04/10/2020 03:46:00 PM
# 49069                  3400               N  04/06/2020 05:08:00 PM
# 49070                   607               N  04/04/2020 08:01:00 PM
#
#       Occurred Date  Occurred Time        Report Date Time Report Date  ...  \
# 0        2020-03-19          435.0  03/19/2020 10:46:00 AM  03/19/2020  ...
# 1        2020-03-06          330.0  03/08/2020 10:22:00 AM  03/08/2020  ...
# 2        2020-03-14         2308.0  03/14/2020 11:08:00 PM  03/14/2020  ...
# 3        2020-06-23          426.0  06/23/2020 04:26:00 AM  06/23/2020  ...
# 4        2020-03-07         2200.0  03/07/2020 10:00:00 PM  03/07/2020  ...
# ...             ...            ...                     ...         ...  ...
# 49066    2020-03-18         1007.0  03/18/2020 10:07:00 AM  03/18/2020  ...
# 49067    2020-04-04         2213.0  04/04/2020 10:13:00 PM  04/04/2020  ...
# 49068    2020-04-10         1546.0  04/10/2020 04:46:00 PM  04/10/2020  ...
# 49069    2020-04-06         1708.0  04/06/2020 05:08:00 PM  04/06/2020  ...
# 49070    2020-04-04         2001.0  04/04/2020 08:01:00 PM  04/04/2020  ...
#
#        Census Tract Clearance Status Clearance Date  UCR Category  \
# 0               NaN              NaN            NaN           NaN
# 1               NaN                N     03/16/2020           23F
# 2               NaN                C     03/15/2020           NaN
# 3               NaN              NaN            NaN           11C
# 4               NaN              NaN            NaN           NaN
# ...             ...              ...            ...           ...
# 49066         18.35                N     03/23/2020           240
# 49067           NaN                C     04/05/2020           NaN
# 49068         24.22              NaN            NaN           NaN
# 49069           NaN              NaN            NaN           NaN
# 49070           NaN                C     04/04/2020           23C
#
#        Category Description X-coordinate Y-coordinate   Latitude  Longitude  \
# 0                       NaN    3127385.0    3127385.0  30.423368 -97.697147
# 1                     Theft    3116318.0    3116318.0  30.232921 -97.737399
# 2                       NaN    3123129.0    3123129.0  30.303287 -97.713917
# 3                      Rape          0.0          0.0        NaN        NaN
# 4                       NaN    3112984.0    3112984.0  30.265437 -97.747088
# ...                     ...          ...          ...        ...        ...
# 49066            Auto Theft    3140018.0    3140018.0  30.385045 -97.658117
# 49067                   NaN    3107822.0    3107822.0  30.438232 -97.758836
# 49068                   NaN    3100503.0    3100503.0  30.189417 -97.788637
# 49069                   NaN    3128170.0    3128170.0  30.349500 -97.696676
# 49070                 Theft    3111086.0    3111086.0  30.218415 -97.754358
#
#                           Location
# 0      (30.42336836, -97.69714681)
# 1      (30.23292142, -97.73739875)
# 2      (30.30328695, -97.71391722)
# 3                              NaN
# 4      (30.26543655, -97.74708803)
# ...                            ...
# 49066  (30.38504521, -97.65811749)
# 49067  (30.43823214, -97.75883565)
# 49068  (30.18941679, -97.78863679)
# 49069  (30.34950001, -97.69667616)
# 49070  (30.21841503, -97.75435779)
#
# [49071 rows x 28 columns]

# %%
#Grab only a few needed columns from main data set for line graphs
crime_data_selection_2019 = drug2019_clean_df[["Incident Number", "Highest Offense Description", "Highest Offense Code", "Family Violence", "Occurred Date", "Occurred Time", "Report Date Time", "Location Type", "Address"]]
crime_data_selection_2019 = crime_data_selection_2019.copy()
crime_data_selection_2019["Month Occurred"] = pd.DatetimeIndex(crime_data_selection_2019["Occurred Date"]).month
crime_data_selection_2019["Month Occurred"] = crime_data_selection_2019["Month Occurred"].apply(lambda x: calendar.month_name[x])
crime_data_selection_months_2019 = crime_data_selection_2019[["Highest Offense Description","Month Occurred"]]

crime_data_selection_2020 = drug2020_clean_df[["Incident Number", "Highest Offense Description", "Highest Offense Code", "Family Violence", "Occurred Date", "Occurred Time", "Report Date Time", "Location Type", "Address"]]
crime_data_selection_2020 = crime_data_selection_2020.copy()
crime_data_selection_2020["Month Occurred"] = pd.DatetimeIndex(crime_data_selection_2020["Occurred Date"]).month
crime_data_selection_2020["Month Occurred"] = crime_data_selection_2020["Month Occurred"].apply(lambda x: calendar.month_name[x])
crime_data_selection_months_2020 = crime_data_selection_2020[["Highest Offense Description","Month Occurred"]]

# %%
drugrelated2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("Drug Related")]
print(f"drug related 2019: {len(drugrelated2019)}")

drugrelated2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("Drug Related")]
print(f"drug related 2020: {len(drugrelated2020)}")
# Out:
# drug related 2019: 1549
# drug related 2020: 1161

# %%
plt.bar(["2019","2020"], [len(drugrelated2019), len(drugrelated2020)], color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("# of Drug Related Incidents")
plt.title("Drug Related Incidents 2019 vs 2020")
plt.savefig('drugrelated.bar.png')
plt.show()

# %%
#Convert object occurred date to timestamp
#crime_data_df["Occurred Date"] = pd.to_datetime(crime_data_df["Occurred Date"])
#crime_data_df["Occurred Date"] = pd.arrays.DatetimeArray(crime_data_df["Occurred Date"])
drug2019bymonth = crime_data_selection_months_2019[crime_data_selection_months_2019['Highest Offense Description'].str.contains("Drug Related")]
summary_drug2019bymonth = drug2019bymonth.groupby("Month Occurred").count()

drug2020bymonth = crime_data_selection_months_2020[crime_data_selection_months_2020['Highest Offense Description'].str.contains("Drug Related")]
summary_drug2020bymonth = drug2020bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_drug2019bymonth = summary_drug2019bymonth.reindex(month_order, axis=0)
summary_drug2020bymonth = summary_drug2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_drug2019bymonth,label='2019 Drug Related Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_drug2020bymonth,label='2020 Drug Related Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("# of Drug Related Incidents")
plt.title("Drug Related Incidents by Month 2019 vs 2020")
plt.savefig('drugrelated.line.png')
plt.show()

# %%
cardabuse2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("CARD ABUSE")]
print(f"card abuse 2019: {len(cardabuse2019)}")

cardabuse2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("CARD ABUSE")]
print(f"card abuse 2020: {len(cardabuse2020)}")
# Out:
# card abuse 2019: 858
# card abuse 2020: 666

# %%
plt.bar(["2019","2020"], [len(cardabuse2019), len(cardabuse2020)],color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Total Card Abuse Incidents")
plt.title("Card Abuse Incidents 2019 vs 2020")
plt.savefig('cardabuse.bar.png')
plt.show()

# %%
#Convert object occurred date to timestamp
#crime_data_df["Occurred Date"] = pd.to_datetime(crime_data_df["Occurred Date"])
#crime_data_df["Occurred Date"] = pd.arrays.DatetimeArray(crime_data_df["Occurred Date"])
cardabuse2019bymonth = crime_data_selection_months_2019[crime_data_selection_months_2019['Highest Offense Description'].str.contains("CARD ABUSE")]
summary_cardabuse2019bymonth = cardabuse2019bymonth.groupby("Month Occurred").count()

cardabuse2020bymonth = crime_data_selection_months_2020[crime_data_selection_months_2020['Highest Offense Description'].str.contains("CARD ABUSE")]
summary_cardabuse2020bymonth = cardabuse2020bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_cardabuse2019bymonth = summary_cardabuse2019bymonth.reindex(month_order, axis=0)
summary_cardabuse2020bymonth = summary_cardabuse2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_cardabuse2019bymonth,label='2019 Card Abuse Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_cardabuse2020bymonth,label='2020 Card Abuse Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("# of Card Abuse Incidents")
plt.title("Card Abuse Incidents by Month 2019 vs 2020")
plt.savefig('cardabuse.line.png')
plt.show()

# %%
identitytheft2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("IDENTITY THEFT")]
print(f"identitytheft2019: {len(identitytheft2019)}")

identitytheft2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("IDENTITY THEFT")]
print(f"identitytheft 2020: {len(identitytheft2020)}")
# Out:
# identitytheft2019: 481
# identitytheft 2020: 575

# %%
plt.bar(["2019","2020"], [len(identitytheft2019), len(identitytheft2020)], color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Total Identity Theft Incidents")
plt.title("Identity Theft Incidents 2019 vs 2020")
plt.savefig('identitytheft.bar.png')
plt.show()

# %%
#Convert object occurred date to timestamp
#crime_data_df["Occurred Date"] = pd.to_datetime(crime_data_df["Occurred Date"])
#crime_data_df["Occurred Date"] = pd.arrays.DatetimeArray(crime_data_df["Occurred Date"])
identitythef2019bymonth = crime_data_selection_months_2019[crime_data_selection_months_2019['Highest Offense Description'].str.contains("IDENTITY THEFT")]
summary_identitythef2019bymonth = identitythef2019bymonth.groupby("Month Occurred").count()

identitythef2019bymonth = crime_data_selection_months_2020[crime_data_selection_months_2020['Highest Offense Description'].str.contains("IDENTITY THEFT")]
summary_identitythef2020bymonth = identitythef2019bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_identitythef2019bymonth = summary_identitythef2019bymonth.reindex(month_order, axis=0)
summary_identitythef2020bymonth = summary_identitythef2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_identitythef2019bymonth,label='2019 Identity Theft Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_identitythef2020bymonth,label='2020 Identity Theft Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("# of Identity Theft Incidents")
plt.title("Identity Theft Incidents by Month 2019 vs 2020")
plt.savefig('identitytheft.line.png')
plt.show()

# %%
fraud2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("FRAUD")]
print(f"fraud 2019: {len(fraud2019)}")

fraud2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("FRAUD")]
print(f"fraud 2020: {len(fraud2020)}")
# Out:
# fraud 2019: 768
# fraud 2020: 801

# %%
plt.bar(["2019","2020"], [len(fraud2019), len(fraud2020)], color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Total Fraud Incidents")
plt.title("Fraud Incidents 2019 vs 2020")
plt.show()

# %%
solicitation2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("SOLICITATION")]
print(f"solicitation 2019: {len(solicitation2019)}")

solicitation2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("SOLICITATION")]
print(f"solicitation 2020: {len(solicitation2020)}")
# Out:
# solicitation 2019: 40
# solicitation 2020: 11

# %%
plt.bar(["2019","2020"], [len(solicitation2019), len(solicitation2020)], color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Total Solicitation Incidents")
plt.title("Solicitation Incidents 2019 vs 2020")
plt.savefig('solicitation.bar.png')
plt.show()

# %%
solicitation2019bymonth = crime_data_selection_months_2019[crime_data_selection_months_2019['Highest Offense Description'].str.contains("SOLICITATION")]
summary_solicitation2019bymonth = solicitation2019bymonth.groupby("Month Occurred").count()

solicitation2020bymonth = crime_data_selection_months_2020[crime_data_selection_months_2020['Highest Offense Description'].str.contains("SOLICITATION")]
summary_solicitation2020bymonth = solicitation2020bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_solicitation2019bymonth = summary_solicitation2019bymonth.reindex(month_order, axis=0)
summary_solicitation2020bymonth = summary_solicitation2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_solicitation2019bymonth,label='2019 Solicitation Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_solicitation2020bymonth,label='2020 Solicitation Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("# of Solicitation Incidents")
plt.title("Solicitation Incidents by month 2019 vs 2020")
plt.savefig('solicitation.line.png')
plt.show()

# %%
suspiciousperson2019 = drug2019_clean_df[drug2019_clean_df['Highest Offense Description'].str.contains("SUSPICIOUS PERSON")]
print(f"suspiciousperson 2019: {len(suspiciousperson2019)}")

suspiciousperson2020 = drug2020_clean_df[drug2020_clean_df['Highest Offense Description'].str.contains("SUSPICIOUS PERSON")]
print(f"suspiciousperson 2020: {len(suspiciousperson2020)}")
# Out:
# suspiciousperson 2019: 386
# suspiciousperson 2020: 615

# %%
plt.bar(["2019","2020"], [len(suspiciousperson2019), len(suspiciousperson2020)], color='tab:orange', alpha=0.9, align="center")
plt.xlabel("Year")
plt.xticks(rotation=90)
plt.ylabel("Total Suspicious Person Incidents")
plt.title("Suspicious Person Incidents 2019 vs 2020")
plt.savefig('suspicious.bar.png')
plt.show()

# %%
#Convert object occurred date to timestamp
#crime_data_df["Occurred Date"] = pd.to_datetime(crime_data_df["Occurred Date"])
#crime_data_df["Occurred Date"] = pd.arrays.DatetimeArray(crime_data_df["Occurred Date"])
suspiciousperson2019bymonth = crime_data_selection_months_2019[crime_data_selection_months_2019['Highest Offense Description'].str.contains("SUSPICIOUS PERSON")]
summary_suspiciousperson2019bymonth = suspiciousperson2019bymonth.groupby("Month Occurred").count()

suspiciousperson2020bymonth = crime_data_selection_months_2020[crime_data_selection_months_2020['Highest Offense Description'].str.contains("SUSPICIOUS PERSON")]
summary_suspiciousperson2020bymonth = suspiciousperson2020bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_suspiciousperson2019bymonth = summary_suspiciousperson2019bymonth.reindex(month_order, axis=0)
summary_suspiciousperson2020bymonth = summary_suspiciousperson2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_suspiciousperson2019bymonth,label='2019 Suspicious Person Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_suspiciousperson2020bymonth,label='2020 Suspicious Person Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("# of Suspicious Person Incidents")
plt.title("Suspicious Person Incidents by month 2019 vs 2020")
plt.savefig('suspiciousperson.line.png')
plt.show()

# %%
crime_data_selection_months_2019
# Out:
#           Highest Offense Description Month Occurred
# 0      ASSAULT  CONTACT-SEXUAL NATURE       February
# 1                                 DWI           July
# 2                    PROTECTIVE ORDER          March
# 3         AGG ASLT STRANGLE/SUFFOCATE          March
# 4               BURGLARY OF RESIDENCE          April
# ...                               ...            ...
# 52761              FAMILY DISTURBANCE           June
# 52762     AGG ASLT STRANGLE/SUFFOCATE       February
# 52763      WARRANT ARREST NON TRAFFIC           July
# 52764  TERRORISTIC THREAT-FAM/DAT VIO            May
# 52765         CHILD CUSTODY INTERFERE           July
#
# [52766 rows x 2 columns]

# %%
# Total Number of Incidents 
# Get months column and groupby for line graph 
totalincidents2019bymonth = crime_data_selection_months_2019["Incident Number"]
summary_totalincidents2019bymonth = totalincidents2019bymonth.groupby("Month Occurred").count()

totalincidents2020bymonth = crime_data_selection_months_2020[Incident Number"]
summary_totalincidents2020bymonth = totalincidents2020bymonth.groupby("Month Occurred").count()

month_order = ['February', 'March', 'April', 'May', 'June', 'July']
summary_totalincidents2019bymonth  = summary_totalincidents2019bymonth .reindex(month_order, axis=0)
summary_totalincidents2020bymonth = summary_totalincidents2020bymonth.reindex(month_order, axis=0)

plt.plot(summary_totalincidents2019bymonth ,label='2019 Crime Incidents', linewidth=2,color='tab:gray')
plt.plot(summary_totalincidents2020bymonth,label='2020 Crime Incidents', linewidth=2,color='tab:orange')
plt.legend()
plt.xlabel("Month")
plt.ylabel("Total Crime Incidents")
plt.title("Total Crime Incidents 2019 vs 2020")
plt.savefig('overallcrime.line.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Incident Number'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-3b016ec78b80> in <module>
#       1 # Total Number of Incidents
#       2 # Get months column and groupby for line graph
# ----> 3 totalincidents2019bymonth = crime_data_selection_months_2019["Incident Number"]
#       4 summary_totalincidents2019bymonth = totalincidents2019bymonth.groupby("Month Occurred").count()
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Incident Number'

# %%
totalincidents_by_month_2019
# Out:
#                 Highest Offense Description
# Month Occurred
# February                               7551
# March                                  9058
# April                                  8480
# May                                    9429
# June                                   8889
# July                                   9359

# %%
totalincidents_by_month_2019.sum()
# Out:
# Highest Offense Description    52766
# dtype: int64

# %%
totalincidents_by_month_2020
# Out:
#                 Highest Offense Description
# Month Occurred
# February                               8107
# March                                  8743
# April                                  7744
# May                                    8680
# June                                   7791
# July                                   8006

# %%
totalincidents_by_month_2020.sum()
# Out:
# Highest Offense Description    49071
# dtype: int64

# %%
month_labels = ['February', 'March', 'April', 'May', 'June', 'July']
x_2019 = totalincidents_by_month_2019
x_2020 = totalincidents_by_month_2020

x = np.arange(len(month_labels))  # the label locations
width = 0.1  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, [x_2019], width, label='Men')
rects2 = ax.bar(x + width/2, [x_2020], width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-5838d3eea027> in <module>
#       7
#       8 fig, ax = plt.subplots()
# ----> 9 rects1 = ax.bar(x - width/2, [x_2019], width, label='Men')
#      10 rects2 = ax.bar(x + width/2, [x_2020], width, label='Women')
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2372         x, height, width, y, linewidth = np.broadcast_arrays(
#    2373             # Make args iterable too.
# -> 2374             np.atleast_1d(x), height, width, y, linewidth)
#    2375
#    2376         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     260         raise TypeError('broadcast_arrays() got an unexpected keyword '
#     261                         'argument {!r}'.format(list(kwargs.keys())[0]))
# --> 262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
#     264     shape = _broadcast_shape(*args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in <listcomp>(.0)
#     260         raise TypeError('broadcast_arrays() got an unexpected keyword '
#     261                         'argument {!r}'.format(list(kwargs.keys())[0]))
# --> 262     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     263
#     264     shape = _broadcast_shape(*args)
#
# ValueError: cannot copy sequence with size 6 to array axis with dimension 1
